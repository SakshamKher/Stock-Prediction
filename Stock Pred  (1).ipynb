# %%
import pandas as pd

# %%
df = pd.read_csv(r'\Users\Saksham\Downloads\MSFT.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060809
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062980
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064067
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062437
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061351
# ...          ...         ...         ...         ...         ...         ...
# 9264  2022-12-13  261.690002  263.920013  253.070007  256.920013  256.920013
# 9265  2022-12-14  257.130005  262.589996  254.309998  257.220001  257.220001
# 9266  2022-12-15  253.720001  254.199997  247.339996  249.009995  249.009995
# 9267  2022-12-16  248.550003  249.839996  243.509995  244.690002  244.690002
# 9268  2022-12-19  244.860001  245.210007  238.710007  240.449997  240.449997
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9264    42196900
# 9265    35410900
# 9266    35560400
# 9267    86088100
# 9268    29668800
#
# [9269 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9264  2022-12-13  256.920013
# 9265  2022-12-14  257.220001
# 9266  2022-12-15  249.009995
# 9267  2022-12-16  244.690002
# 9268  2022-12-19  240.449997
#
# [9269 rows x 2 columns]

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\Saksham\AppData\Local\Temp\ipykernel_1804\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9264   2022-12-13
# 9265   2022-12-14
# 9266   2022-12-15
# 9267   2022-12-16
# 9268   2022-12-19
# Name: Date, Length: 9269, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-12-13  256.920013
# 2022-12-14  257.220001
# 2022-12-15  249.009995
# 2022-12-16  244.690002
# 2022-12-19  240.449997
#
# [9269 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2021-03-25', 
                                '2022-03-23', 
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 100ms/step - loss: 84662.3516 - mean_absolute_error: 289.2261 - val_loss: 92370.5312 - val_mean_absolute_error: 303.8380
# Epoch 2/100
# 7/7 [==============================] - 0s 9ms/step - loss: 84446.7188 - mean_absolute_error: 288.8540 - val_loss: 92153.1719 - val_mean_absolute_error: 303.4802
# Epoch 3/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84231.5859 - mean_absolute_error: 288.4819 - val_loss: 91892.4062 - val_mean_absolute_error: 303.0502
# Epoch 4/100
# 7/7 [==============================] - 0s 8ms/step - loss: 83957.7344 - mean_absolute_error: 288.0059 - val_loss: 91547.2734 - val_mean_absolute_error: 302.4803
# Epoch 5/100
# 7/7 [==============================] - 0s 8ms/step - loss: 83589.1406 - mean_absolute_error: 287.3627 - val_loss: 91086.4766 - val_mean_absolute_error: 301.7175
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 83084.1328 - mean_absolute_error: 286.4860 - val_loss: 90434.2422 - val_mean_absolute_error: 300.6348
# Epoch 7/100
# 7/7 [==============================] - 0s 8ms/step - loss: 82386.2109 - mean_absolute_error: 285.2654 - val_loss: 89564.4219 - val_mean_absolute_error: 299.1846
# Epoch 8/100
# 7/7 [==============================] - 0s 9ms/step - loss: 81500.5234 - mean_absolute_error: 283.7038 - val_loss: 88517.7188 - val_mean_absolute_error: 297.4301
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 80370.8750 - mean_absolute_error: 281.6937 - val_loss: 87034.8984 - val_mean_absolute_error: 294.9268
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 78766.0469 - mean_absolute_error: 278.8401 - val_loss: 85148.8594 - val_mean_absolute_error: 291.7119
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 76875.1406 - mean_absolute_error: 275.4377 - val_loss: 82857.0234 - val_mean_absolute_error: 287.7569
# Epoch 12/100
# 7/7 [==============================] - 0s 9ms/step - loss: 74600.4531 - mean_absolute_error: 271.2682 - val_loss: 80280.3359 - val_mean_absolute_error: 283.2442
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 71857.1406 - mean_absolute_error: 266.1417 - val_loss: 76702.2969 - val_mean_absolute_error: 276.8560
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - loss: 68376.9922 - mean_absolute_error: 259.5638 - val_loss: 73179.8906 - val_mean_absolute_error: 270.4199
# Epoch 15/100
# 7/7 [==============================] - 0s 9ms/step - loss: 64923.5156 - mean_absolute_error: 252.7894 - val_loss: 68978.4062 - val_mean_absolute_error: 262.5363
# Epoch 16/100
# 7/7 [==============================] - 0s 9ms/step - loss: 60571.6953 - mean_absolute_error: 244.0060 - val_loss: 63896.1953 - val_mean_absolute_error: 252.6721
# Epoch 17/100
# 7/7 [==============================] - 0s 8ms/step - loss: 55837.9609 - mean_absolute_error: 234.1115 - val_loss: 58976.0938 - val_mean_absolute_error: 242.7408
# Epoch 18/100
# 7/7 [==============================] - 0s 9ms/step - loss: 51078.9609 - mean_absolute_error: 223.7342 - val_loss: 53615.8984 - val_mean_absolute_error: 231.4366
# Epoch 19/100
# 7/7 [==============================] - 0s 9ms/step - loss: 45967.5664 - mean_absolute_error: 211.9878 - val_loss: 47931.4219 - val_mean_absolute_error: 218.8108
# Epoch 20/100
# 7/7 [==============================] - 0s 8ms/step - loss: 40285.9414 - mean_absolute_error: 198.0938 - val_loss: 41535.4102 - val_mean_absolute_error: 203.6723
# Epoch 21/100
# 7/7 [==============================] - 0s 9ms/step - loss: 34630.6484 - mean_absolute_error: 183.2750 - val_loss: 35727.1992 - val_mean_absolute_error: 188.8763
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 29293.2148 - mean_absolute_error: 168.1945 - val_loss: 30079.4199 - val_mean_absolute_error: 173.2814
# Epoch 23/100
# 7/7 [==============================] - 0s 8ms/step - loss: 24214.0723 - mean_absolute_error: 152.1771 - val_loss: 24493.4180 - val_mean_absolute_error: 156.3336
# Epoch 24/100
# 7/7 [==============================] - 0s 8ms/step - loss: 19022.7441 - mean_absolute_error: 134.0357 - val_loss: 18926.1719 - val_mean_absolute_error: 137.3799
# Epoch 25/100
# 7/7 [==============================] - 0s 9ms/step - loss: 14486.9062 - mean_absolute_error: 115.8848 - val_loss: 14427.1699 - val_mean_absolute_error: 119.8925
# Epoch 26/100
# 7/7 [==============================] - 0s 8ms/step - loss: 10740.0869 - mean_absolute_error: 98.5356 - val_loss: 10623.4277 - val_mean_absolute_error: 102.8127
# Epoch 27/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7701.0449 - mean_absolute_error: 81.6245 - val_loss: 7471.3906 - val_mean_absolute_error: 86.1295
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5213.9380 - mean_absolute_error: 64.4824 - val_loss: 4784.0229 - val_mean_absolute_error: 68.7829
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3381.4023 - mean_absolute_error: 48.6948 - val_loss: 3039.2688 - val_mean_absolute_error: 54.6471
# Epoch 30/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2236.6558 - mean_absolute_error: 38.2203 - val_loss: 1880.6880 - val_mean_absolute_error: 42.7519
# Epoch 31/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1587.5350 - mean_absolute_error: 32.5580 - val_loss: 1124.3046 - val_mean_absolute_error: 32.7312
# Epoch 32/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1236.6110 - mean_absolute_error: 29.6967 - val_loss: 682.4435 - val_mean_absolute_error: 25.0894
# Epoch 33/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1086.5298 - mean_absolute_error: 27.9422 - val_loss: 446.2798 - val_mean_absolute_error: 19.8322
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1026.7291 - mean_absolute_error: 27.0720 - val_loss: 328.3948 - val_mean_absolute_error: 16.5976
# Epoch 35/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1008.9799 - mean_absolute_error: 26.8618 - val_loss: 300.8410 - val_mean_absolute_error: 15.7496
# Epoch 36/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1001.9045 - mean_absolute_error: 26.7614 - val_loss: 248.2130 - val_mean_absolute_error: 14.1157
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1008.2684 - mean_absolute_error: 26.8371 - val_loss: 229.8839 - val_mean_absolute_error: 13.4980
# Epoch 38/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1004.7762 - mean_absolute_error: 26.7987 - val_loss: 254.2942 - val_mean_absolute_error: 14.3175
# Epoch 39/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1006.6035 - mean_absolute_error: 26.8248 - val_loss: 292.3189 - val_mean_absolute_error: 15.4952
# Epoch 40/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1000.4696 - mean_absolute_error: 26.7304 - val_loss: 265.1375 - val_mean_absolute_error: 14.6660
# Epoch 41/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1003.4878 - mean_absolute_error: 26.7734 - val_loss: 248.7072 - val_mean_absolute_error: 14.1348
# Epoch 42/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1000.1246 - mean_absolute_error: 26.7348 - val_loss: 264.5579 - val_mean_absolute_error: 14.6507
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 995.1749 - mean_absolute_error: 26.6556 - val_loss: 296.6182 - val_mean_absolute_error: 15.6289
# Epoch 44/100
# 7/7 [==============================] - 0s 8ms/step - loss: 995.4241 - mean_absolute_error: 26.6700 - val_loss: 282.8634 - val_mean_absolute_error: 15.2203
# Epoch 45/100
# 7/7 [==============================] - 0s 8ms/step - loss: 989.8082 - mean_absolute_error: 26.5814 - val_loss: 275.3414 - val_mean_absolute_error: 14.9906
# Epoch 46/100
# 7/7 [==============================] - 0s 8ms/step - loss: 986.7117 - mean_absolute_error: 26.5452 - val_loss: 293.3819 - val_mean_absolute_error: 15.5401
# Epoch 47/100
# 7/7 [==============================] - 0s 8ms/step - loss: 988.1024 - mean_absolute_error: 26.5822 - val_loss: 305.9464 - val_mean_absolute_error: 15.9388
# Epoch 48/100
# 7/7 [==============================] - 0s 8ms/step - loss: 967.6642 - mean_absolute_error: 26.3007 - val_loss: 377.1025 - val_mean_absolute_error: 18.0542
# Epoch 49/100
# 7/7 [==============================] - 0s 8ms/step - loss: 950.2048 - mean_absolute_error: 26.0414 - val_loss: 294.6684 - val_mean_absolute_error: 15.6122
# Epoch 50/100
# 7/7 [==============================] - 0s 9ms/step - loss: 941.9008 - mean_absolute_error: 25.9607 - val_loss: 333.2823 - val_mean_absolute_error: 16.8259
# Epoch 51/100
# 7/7 [==============================] - 0s 9ms/step - loss: 926.1226 - mean_absolute_error: 25.7190 - val_loss: 261.0338 - val_mean_absolute_error: 14.5813
# Epoch 52/100
# 7/7 [==============================] - 0s 8ms/step - loss: 917.3637 - mean_absolute_error: 25.5689 - val_loss: 310.3273 - val_mean_absolute_error: 16.1481
# Epoch 53/100
# 7/7 [==============================] - 0s 8ms/step - loss: 907.9443 - mean_absolute_error: 25.4472 - val_loss: 249.1907 - val_mean_absolute_error: 14.2222
# Epoch 54/100
# 7/7 [==============================] - 0s 9ms/step - loss: 904.7770 - mean_absolute_error: 25.4116 - val_loss: 221.8678 - val_mean_absolute_error: 13.3045
# Epoch 55/100
# 7/7 [==============================] - 0s 8ms/step - loss: 897.1412 - mean_absolute_error: 25.3689 - val_loss: 262.1636 - val_mean_absolute_error: 14.6536
# Epoch 56/100
# 7/7 [==============================] - 0s 8ms/step - loss: 878.4182 - mean_absolute_error: 25.0344 - val_loss: 213.0253 - val_mean_absolute_error: 13.0059
# Epoch 57/100
# 7/7 [==============================] - 0s 8ms/step - loss: 871.3179 - mean_absolute_error: 24.9568 - val_loss: 237.1033 - val_mean_absolute_error: 13.8512
# Epoch 58/100
# 7/7 [==============================] - 0s 8ms/step - loss: 859.0554 - mean_absolute_error: 24.7449 - val_loss: 212.4455 - val_mean_absolute_error: 13.0012
# Epoch 59/100
# 7/7 [==============================] - 0s 8ms/step - loss: 848.3661 - mean_absolute_error: 24.5978 - val_loss: 252.8631 - val_mean_absolute_error: 14.3841
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 851.6499 - mean_absolute_error: 24.6442 - val_loss: 198.7255 - val_mean_absolute_error: 12.5139
# Epoch 61/100
# 7/7 [==============================] - 0s 8ms/step - loss: 834.6309 - mean_absolute_error: 24.3834 - val_loss: 217.0478 - val_mean_absolute_error: 13.1927
# Epoch 62/100
# 7/7 [==============================] - 0s 8ms/step - loss: 819.9887 - mean_absolute_error: 24.2153 - val_loss: 243.9857 - val_mean_absolute_error: 14.1205
# Epoch 63/100
# 7/7 [==============================] - 0s 8ms/step - loss: 801.2411 - mean_absolute_error: 23.9129 - val_loss: 206.7474 - val_mean_absolute_error: 12.8398
# Epoch 64/100
# 7/7 [==============================] - 0s 8ms/step - loss: 777.4835 - mean_absolute_error: 23.5034 - val_loss: 291.1831 - val_mean_absolute_error: 15.6993
# Epoch 65/100
# 7/7 [==============================] - 0s 8ms/step - loss: 757.3610 - mean_absolute_error: 23.1675 - val_loss: 212.7019 - val_mean_absolute_error: 13.0968
# Epoch 66/100
# 7/7 [==============================] - 0s 9ms/step - loss: 702.2818 - mean_absolute_error: 22.2955 - val_loss: 228.2509 - val_mean_absolute_error: 13.6601
# Epoch 67/100
# 7/7 [==============================] - 0s 8ms/step - loss: 655.2944 - mean_absolute_error: 21.5780 - val_loss: 225.2018 - val_mean_absolute_error: 13.5843
# Epoch 68/100
# 7/7 [==============================] - 0s 8ms/step - loss: 603.4686 - mean_absolute_error: 20.6404 - val_loss: 224.7849 - val_mean_absolute_error: 13.5954
# Epoch 69/100
# 7/7 [==============================] - 0s 9ms/step - loss: 552.2518 - mean_absolute_error: 19.6644 - val_loss: 354.5421 - val_mean_absolute_error: 17.7948
# Epoch 70/100
# 7/7 [==============================] - 0s 9ms/step - loss: 523.7486 - mean_absolute_error: 19.0203 - val_loss: 193.7115 - val_mean_absolute_error: 12.5387
# Epoch 71/100
# 7/7 [==============================] - 0s 8ms/step - loss: 500.0264 - mean_absolute_error: 18.4117 - val_loss: 91.2547 - val_mean_absolute_error: 7.8850
# Epoch 72/100
# 7/7 [==============================] - 0s 8ms/step - loss: 418.5887 - mean_absolute_error: 16.6300 - val_loss: 158.6428 - val_mean_absolute_error: 11.2151
# Epoch 73/100
# 7/7 [==============================] - 0s 8ms/step - loss: 359.6592 - mean_absolute_error: 15.4785 - val_loss: 198.6223 - val_mean_absolute_error: 12.8329
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 327.2067 - mean_absolute_error: 14.4771 - val_loss: 89.7576 - val_mean_absolute_error: 7.9369
# Epoch 75/100
# 7/7 [==============================] - 0s 10ms/step - loss: 277.5758 - mean_absolute_error: 13.2539 - val_loss: 110.9173 - val_mean_absolute_error: 9.0699
# Epoch 76/100
# 7/7 [==============================] - 0s 8ms/step - loss: 231.0087 - mean_absolute_error: 11.9969 - val_loss: 83.4076 - val_mean_absolute_error: 7.6263
# Epoch 77/100
# 7/7 [==============================] - 0s 8ms/step - loss: 200.8134 - mean_absolute_error: 11.2605 - val_loss: 123.9737 - val_mean_absolute_error: 9.7358
# Epoch 78/100
# 7/7 [==============================] - 0s 9ms/step - loss: 178.3343 - mean_absolute_error: 10.5715 - val_loss: 64.8815 - val_mean_absolute_error: 6.6212
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 141.2498 - mean_absolute_error: 8.9180 - val_loss: 31.8484 - val_mean_absolute_error: 4.9549
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 122.3234 - mean_absolute_error: 8.3578 - val_loss: 35.0453 - val_mean_absolute_error: 5.1338
# Epoch 81/100
# 7/7 [==============================] - 0s 9ms/step - loss: 103.8803 - mean_absolute_error: 7.3954 - val_loss: 31.9318 - val_mean_absolute_error: 4.9930
# Epoch 82/100
# 7/7 [==============================] - 0s 9ms/step - loss: 100.8288 - mean_absolute_error: 7.3264 - val_loss: 39.6656 - val_mean_absolute_error: 5.1799
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 85.9336 - mean_absolute_error: 7.0566 - val_loss: 51.9679 - val_mean_absolute_error: 5.7454
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 78.4920 - mean_absolute_error: 6.7227 - val_loss: 65.0210 - val_mean_absolute_error: 6.4096
# Epoch 85/100
# 7/7 [==============================] - 0s 8ms/step - loss: 84.1025 - mean_absolute_error: 7.3474 - val_loss: 66.1634 - val_mean_absolute_error: 6.4738
# Epoch 86/100
# 7/7 [==============================] - 0s 8ms/step - loss: 76.3660 - mean_absolute_error: 7.2805 - val_loss: 41.6803 - val_mean_absolute_error: 5.1249
# Epoch 87/100
# 7/7 [==============================] - 0s 8ms/step - loss: 58.0397 - mean_absolute_error: 5.8554 - val_loss: 39.5809 - val_mean_absolute_error: 5.0242
# Epoch 88/100
# 7/7 [==============================] - 0s 9ms/step - loss: 52.0236 - mean_absolute_error: 5.5457 - val_loss: 33.0378 - val_mean_absolute_error: 4.8705
# Epoch 89/100
# 7/7 [==============================] - 0s 8ms/step - loss: 46.1274 - mean_absolute_error: 5.0088 - val_loss: 45.4654 - val_mean_absolute_error: 5.2342
# Epoch 90/100
# 7/7 [==============================] - 0s 8ms/step - loss: 45.3923 - mean_absolute_error: 5.2241 - val_loss: 38.8113 - val_mean_absolute_error: 4.9909
# Epoch 91/100
# 7/7 [==============================] - 0s 8ms/step - loss: 41.4998 - mean_absolute_error: 4.8662 - val_loss: 42.9294 - val_mean_absolute_error: 5.1178
# Epoch 92/100
# 7/7 [==============================] - 0s 8ms/step - loss: 39.1380 - mean_absolute_error: 4.7757 - val_loss: 40.5710 - val_mean_absolute_error: 5.0414
# Epoch 93/100
# 7/7 [==============================] - 0s 8ms/step - loss: 38.0748 - mean_absolute_error: 4.8294 - val_loss: 31.6311 - val_mean_absolute_error: 4.8484
# Epoch 94/100
# 7/7 [==============================] - 0s 8ms/step - loss: 38.8022 - mean_absolute_error: 4.9737 - val_loss: 31.4874 - val_mean_absolute_error: 4.8434
# Epoch 95/100
# 7/7 [==============================] - 0s 8ms/step - loss: 37.7691 - mean_absolute_error: 4.8597 - val_loss: 32.1796 - val_mean_absolute_error: 4.8541
# Epoch 96/100
# 7/7 [==============================] - 0s 8ms/step - loss: 37.0255 - mean_absolute_error: 4.7099 - val_loss: 35.1323 - val_mean_absolute_error: 4.8893
# Epoch 97/100
# 7/7 [==============================] - 0s 8ms/step - loss: 33.5672 - mean_absolute_error: 4.5161 - val_loss: 35.9801 - val_mean_absolute_error: 4.8967
# Epoch 98/100
# 7/7 [==============================] - 0s 8ms/step - loss: 31.9812 - mean_absolute_error: 4.3892 - val_loss: 67.1440 - val_mean_absolute_error: 6.4678
# Epoch 99/100
# 7/7 [==============================] - 0s 9ms/step - loss: 37.6937 - mean_absolute_error: 4.9451 - val_loss: 69.4046 - val_mean_absolute_error: 6.6038
# Epoch 100/100
# 7/7 [==============================] - 0s 8ms/step - loss: 31.7934 - mean_absolute_error: 4.4813 - val_loss: 41.2072 - val_mean_absolute_error: 5.0617

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17784\378089537.py in <module>
# ----> 1 val_predictions = model.predict(X_val).flatten()
#       2
#       3 plt.plot(dates_val, val_predictions)
#       4 plt.plot(dates_val, y_val)
#       5 plt.legend(['Validation Predictions', 'Validation Observations'])
#
# NameError: name 'model' is not defined

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
